# %%
import pandas as pd

# %%
df = pd.read_excel('data/สภาพครัวเรือน.xlsx')
df.head()
# Out:
#   House Number      ข้อมูลการใช้ไฟฟ้า ข้อมูลการใช้น้ำบริโภค-แหล่งที่มา  \
# 0            1  มีและมีหม้อมิเตอร์เอง                             ซื้อ
# 1            2  มีและมีหม้อมิเตอร์เอง                             ซื้อ
# 2            3  มีและมีหม้อมิเตอร์เอง                             ซื้อ
# 3            5  มีและมีหม้อมิเตอร์เอง                             ซื้อ
# 4            6  มีและมีหม้อมิเตอร์เอง                           บ่อน้ำ
#
#   ข้อมูลการใช้น้ำบริโภค ข้อมูลการใช้น้ำอุปโภค-แหล่งที่มา  \
# 0          มีดื่มตลอดปี                            ประปา
# 1          มีดื่มตลอดปี                            ประปา
# 2                   NaN                            ประปา
# 3          มีดื่มตลอดปี                            ประปา
# 4          มีดื่มตลอดปี                           บ่อน้ำ
#
#                                ข้อมูลการใช้น้ำอุปโภค         ลักษณะของบ้าน  \
# 0                       มีใช้เป็นช่วงๆ(ฤดูฝนน้ำขุ่น)           บ้านสองชั้น
# ...
